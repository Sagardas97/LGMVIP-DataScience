# %% [markdown]
# <H1 style="color:SlateBlue;"> Lets Grow More Virtual Internship Program </H1>

# %% [markdown]
# <b> Data Science Virtual Internship </b>

# %% [markdown]
# <b> Task two of Intermediate: Prediction using Decision Tree Algorithm </b>

# %% [markdown]
# <b> Submitted by Sagar Das </b>

# %% [markdown]
# <H3 style="color:SlateBlue;">Using the ‘Iris’ dataset, constructing a decision tree and representing it visually, so that if we feed any new data to this classifier, it would be able to predict the right class accordingly.</H3>

# %% [markdown]
# <H3 style="color:Crimson;"> Loading Required Python Libraries </H3>

# %%
import pandas as pd
import numpy as np
import sklearn.datasets as datasets
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <h3 style="color:Crimson;">loading and checking the dataset</h3>

# %%
data=datasets.load_iris()
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# <b> So there are no null values. </b>

# %% [markdown]
# <h3 style="color:Crimson;">Splitting the Dataset into Train and Test</h3>

# %%
X = df
y = data.target
X_train,X_test,y_train,y_test = train_test_split(X, y, random_state=0,test_size=.2)

# %% [markdown]
# <h3 style="color:Crimson;"> Fitting the Decision Tree</h3>

# %%
dtree=DecisionTreeClassifier(max_depth=5,criterion='entropy')
dtree.fit(X_train,y_train)
y_predict = dtree.predict(X_test)

print("Fitted the Decision Tree Classifer!")
# Out:
# Fitted the Decision Tree Classifer!

# %% [markdown]
# <h3 style="color:Crimson;"> Model Evaluation </h3>

# %% [markdown]
# <li><b> Confusion Matrix </b></li>

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %% [markdown]
# <li><b> Classification Report </b></li>

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# <li><b> Accuracy Score </b></li>

# %%
print("Accuracy Score:%.2f"%accuracy_score(y_test,y_predict))
# Out:
# Accuracy Score:1.00

# %% [markdown]
# <b>We see that the Precision, Recall, F1-Score are 100% also we have 100% accuracy score which means the model is fitted well and works nicely.</b>

# %% [markdown]
# <h3 style="color:Crimson;"> Visualizing the Decision Tree</h3>

# %%
plt.figure(figsize=(18,12))
tree.plot_tree(dtree,feature_names=data.feature_names, class_names = data.target_names, filled=True,rounded=True)
plt.title("Decision Tree",fontsize=25,color="GRAY")
plt.show()

# %% [markdown]
# <h3 style="color:Crimson;"> User Input Prediction</h3>

# %%
input0 = input("Please input Sepal Length, Sepal Width, Petal Length, Petal Width in centemeters, separated by commas:").split(',' or ', ' or ' ,')
input1=[]
for i in input0:
    input1.append(float(i))
print(input1)    
Predicted_Class = dtree.predict([input1])
print(data.target_names[Predicted_Class][0])
# Out:
# Please input Sepal Length, Sepal Width, Petal Length, Petal Width in centemeters, separated by commas: 5.1, 3.5, 3.5, 5.1
# [5.1, 3.5, 3.5, 5.1]
# versicolor
